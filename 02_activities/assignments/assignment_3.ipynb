# %% [markdown]
# # Assignment 3

# %% [markdown]
# In this assigment, we will work with the *Forest Fire* data set. Please download the data from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/dataset/162/forest+fires). Extract the data files into the subdirectory: `../data/fires/` (relative to `./src/`).
#
# ## Objective
#
# + The model objective is to predict the area affected by forest fires given the features set.
# + The objective of this exercise is to assess your ability to construct and evaluate model pipelines.
# + Please note: the instructions are not meant to be 100% prescriptive, but instead they are a set of minimum requirements. If you find predictive performance gains by applying additional steps, by all means show them.

# %% [markdown]
# ## Variable Description
#
# From the description file contained in the archive (`forestfires.names`), we obtain the following variable descriptions:
#
# 1. X - x-axis spatial coordinate within the Montesinho park map: 1 to 9
# 2. Y - y-axis spatial coordinate within the Montesinho park map: 2 to 9
# 3. month - month of the year: "jan" to "dec"
# 4. day - day of the week: "mon" to "sun"
# 5. FFMC - FFMC index from the FWI system: 18.7 to 96.20
# 6. DMC - DMC index from the FWI system: 1.1 to 291.3
# 7. DC - DC index from the FWI system: 7.9 to 860.6
# 8. ISI - ISI index from the FWI system: 0.0 to 56.10
# 9. temp - temperature in Celsius degrees: 2.2 to 33.30
# 10. RH - relative humidity in %: 15.0 to 100
# 11. wind - wind speed in km/h: 0.40 to 9.40
# 12. rain - outside rain in mm/m2 : 0.0 to 6.4
# 13. area - the burned area of the forest (in ha): 0.00 to 1090.84

# %% [markdown]
# ### Specific Tasks
#
# + Construct four model pipelines, out of combinations of the following components:
#
#     + Preprocessors:
#
#         - A simple processor that only scales numeric variables and recodes categorical variables.
#         - A transformation preprocessor that scales numeric variables and applies a non-linear transformation.
#
#     + Regressor:
#
#         - A baseline regressor, which could be a [K-nearest neighbours model](https://open.spotify.com/track/4R3AU2pjv8ge2siX1fVbZs?si=b2712f32da0e4358) or a simple [linear regression model](https://scikit-learn.org/stable/modules/linear_model.html)
#         - An advanced regressor of your choice (e.g., Random Forest, Neural Network, etc.)
#
# + Evaluate tune and evaluate each of the four model pipelines.
#
#     - Select a [performance metric](https://scikit-learn.org/stable/modules/linear_model.html) out of the following options: explained variance, max error, root mean squared error (RMSE), mean absolute error (MAE), r-squared.
#     - *TIPS*:
#
#         * Out of the suggested metrics above, [some are correlation metrics, but this is a prediction problem](https://www.tmwr.org/performance#performance). Choose wisely (and don't choose the incorrect options.)
#
# + Select the best-performing model and explain its predictions.
#
#     - Provide local explanations.
#     - Obtain global explanations and recommend a variable selection strategy.
#
# + Export your model as a pickle file.
#
#
# You can work on the Jupyter notebook, as this experiment is fairly short (no need to use sacred).

# %% [markdown]
# # Load the data
#
# Assuming that the files `adult.data` and `adult.test` are in `../data/adult/`, then you can use the code below to load them.

# %%
import pandas as pd
columns = [
    'coord_x', 'coord_y', 'month', 'day', 'ffmc', 'dmc', 'dc', 'isi', 'temp', 'rh', 'wind', 'rain', 'area' 
]
fires_dt = (pd.read_csv('../../05_src/data/fires/forestfires.csv', header = None, names = columns, skiprows=1))

# %%
from sklearn.preprocessing import StandardScaler 
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder , StandardScaler , RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.svm import SVR

# %% [markdown]
# # Get X and Y
#
# Create the features data frame and target data.

# %%
X = fires_dt.drop(columns='area')
Y = fires_dt[['area']]

# %%
scaler = StandardScaler()
X_cols = X[['ffmc' , 'dmc' , 'dc' , 'isi' , 'temp' , 'rh' , 'wind' , 'rain']]

scaler.fit(X_cols)
scaled_x = scaler.transform(X_cols)

scaled_df = pd.DataFrame(scaled_x, columns=X_cols.columns)
fig , ( ax1 , ax2 ) = plt.subplots(nrows=1 , ncols=2, figsize=(20,6))

ax1.boxplot(scaled_df, labels=list(scaled_df.columns))
ax2.boxplot(X[['ffmc' , 'dmc' , 'dc' , 'isi' , 'temp' , 'rh' , 'wind' , 'rain']], labels=list(X[['ffmc' , 'dmc' , 'dc' , 'isi' , 'temp' , 'rh' , 'wind' , 'rain']].columns))

plt.show()
plt.clf()

# %% [markdown]
# # Preprocessing
#
# Create two [Column Transformers](https://scikit-learn.org/stable/modules/generated/sklearn.compose.ColumnTransformer.html), called preproc1 and preproc2, with the following guidelines:
#
# - Numerical variables
#
#     * (Preproc 1 and 2) Scaling: use a scaling method of your choice (Standard, Robust, Min-Max).
#     * Preproc 2 only:
#
#         + Choose a transformation for any of your input variables (or several of them). Evaluate if this transformation is convenient.
#         + The choice of scaler is up to you.
#
# - Categorical variables:
#
#     * (Preproc 1 and 2) Apply [one-hot encoding](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html) where appropriate.
#
#
# + The only difference between preproc1 and preproc2 is the non-linear transformation of the numerical variables.

# %% [markdown]
# ### Preproc 1
#
# Create preproc1 below.
#
# + Numeric: scaled variables, no other transforms.
# + Categorical: one-hot encoding.

# %%
# preproc1
preproc1 = ColumnTransformer([
    ('num_transformer' , StandardScaler() , [ 'ffmc' , 'dmc' , 'dc' , 'isi' , 'temp' , 'rh' , 'wind' , 'rain' ] ),
    ('col_transformer' , OneHotEncoder(handle_unknown='infrequent_if_exist') , [ 'month' ] )
])

preproc1
# Out:
# ColumnTransformer(transformers=[('num_transformer', StandardScaler(),
#                                  ['ffmc', 'dmc', 'dc', 'isi', 'temp', 'rh',
#                                   'wind', 'rain']),
#                                 ('col_transformer',
#                                  OneHotEncoder(handle_unknown='infrequent_if_exist'),
#                                  ['month'])])

# %% [markdown]
# ### Preproc 2
#
# Create preproc1 below.
#
# + Numeric: scaled variables, non-linear transformation to one or more variables.
# + Categorical: one-hot encoding.

# %%
# preproc2
preproc2 = ColumnTransformer([
    ('num_transformer' , RobustScaler() , [ 'ffmc' , 'dmc' , 'dc' , 'isi' , 'temp' , 'rh' , 'wind' , 'rain' ]),
    ('col_transformer' , OneHotEncoder(handle_unknown='infrequent_if_exist') , [ 'month' ])
])

preproc2
# Out:
# ColumnTransformer(transformers=[('num_transformer', RobustScaler(),
#                                  ['ffmc', 'dmc', 'dc', 'isi', 'temp', 'rh',
#                                   'wind', 'rain']),
#                                 ('col_transformer',
#                                  OneHotEncoder(handle_unknown='infrequent_if_exist'),
#                                  ['month'])])

# %% [markdown]
# ## Model Pipeline
#
#
# Create a [model pipeline](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html):
#
# + Add a step labelled `preprocessing` and assign the Column Transformer from the previous section.
# + Add a step labelled `regressor` and assign a regression model to it.
#
# ## Regressor
#
# + Use a regression model to perform a prediction.
#
#     - Choose a baseline regressor, tune it (if necessary) using grid search, and evaluate it using cross-validation.
#     - Choose a more advance regressor, tune it (if necessary) using grid search, and evaluate it using cross-validation.
#     - Both model choices are up to you, feel free to experiment.

# %%
# Pipeline A = preproc1 + baseline
pipe1_base = Pipeline([
    ('preproc1' , preproc1),
    ('nearest_neighbour' , KNeighborsRegressor(n_neighbors=6 , weights='uniform' , p=2))
])

pipe1_base.get_params()
# Out:
# {'memory': None,
#  'steps': [('preproc1',
#    ColumnTransformer(transformers=[('num_transformer', StandardScaler(),
#                                     ['ffmc', 'dmc', 'dc', 'isi', 'temp', 'rh',
#                                      'wind', 'rain']),
#                                    ('col_transformer',
#                                     OneHotEncoder(handle_unknown='infrequent_if_exist'),
#                                     ['month'])])),
#   ('nearest_neighbour', KNeighborsRegressor(n_neighbors=6))],
#  'verbose': False,
#  'preproc1': ColumnTransformer(transformers=[('num_transformer', StandardScaler(),
#                                   ['ffmc', 'dmc', 'dc', 'isi', 'temp', 'rh',
#                                    'wind', 'rain']),
#                                  ('col_transformer',
#                                   OneHotEncoder(handle_unknown='infrequent_if_exist'),
#                                   ['month'])]),
#  'nearest_neighbour': KNeighborsRegressor(n_neighbors=6),
#  'preproc1__n_jobs': None,
#  'preproc1__remainder': 'drop',
#  'preproc1__sparse_threshold': 0.3,
#  'preproc1__transformer_weights': None,
#  'preproc1__transformers': [('num_transformer',
#    StandardScaler(),
#    ['ffmc', 'dmc', 'dc', 'isi', 'temp', 'rh', 'wind', 'rain']),
#   ('col_transformer',
#    OneHotEncoder(handle_unknown='infrequent_if_exist'),
#    ['month'])],
#  'preproc1__verbose': False,
#  'preproc1__verbose_feature_names_out': True,
#  'preproc1__num_transformer': StandardScaler(),
#  'preproc1__col_transformer': OneHotEncoder(handle_unknown='infrequent_if_exist'),
#  'preproc1__num_transformer__copy': True,
#  'preproc1__num_transformer__with_mean': True,
#  'preproc1__num_transformer__with_std': True,
#  'preproc1__col_transformer__categories': 'auto',
#  'preproc1__col_transformer__drop': None,
#  'preproc1__col_transformer__dtype': numpy.float64,
#  'preproc1__col_transformer__feature_name_combiner': 'concat',
#  'preproc1__col_transformer__handle_unknown': 'infrequent_if_exist',
#  'preproc1__col_transformer__max_categories': None,
#  'preproc1__col_transformer__min_frequency': None,
#  'preproc1__col_transformer__sparse_output': True,
#  'nearest_neighbour__algorithm': 'auto',
#  'nearest_neighbour__leaf_size': 30,
#  'nearest_neighbour__metric': 'minkowski',
#  'nearest_neighbour__metric_params': None,
#  'nearest_neighbour__n_jobs': None,
#  'nearest_neighbour__n_neighbors': 6,
#  'nearest_neighbour__p': 2,
#  'nearest_neighbour__weights': 'uniform'}

# %%
# Pipeline B = preproc2 + baseline
pipe2_base = Pipeline([
    ('preproc2' , preproc2),
    ('nearest_neighbour' , KNeighborsRegressor(n_neighbors=6 , weights='uniform' , p=2))
])

# %%
# Pipeline C = preproc1 + advanced model
pipe1_adv = Pipeline([
    ('preproc1' , preproc1),
    ('adaboost_reg' , AdaBoostRegressor(estimator=DecisionTreeRegressor() , n_estimators=50 , random_state=42))
])

pipe1_adv.get_params()
# Out:
# {'memory': None,
#  'steps': [('preproc1',
#    ColumnTransformer(transformers=[('num_transformer', StandardScaler(),
#                                     ['ffmc', 'dmc', 'dc', 'isi', 'temp', 'rh',
#                                      'wind', 'rain']),
#                                    ('col_transformer',
#                                     OneHotEncoder(handle_unknown='infrequent_if_exist'),
#                                     ['month'])])),
#   ('adaboost_reg',
#    AdaBoostRegressor(estimator=DecisionTreeRegressor(), random_state=42))],
#  'verbose': False,
#  'preproc1': ColumnTransformer(transformers=[('num_transformer', StandardScaler(),
#                                   ['ffmc', 'dmc', 'dc', 'isi', 'temp', 'rh',
#                                    'wind', 'rain']),
#                                  ('col_transformer',
#                                   OneHotEncoder(handle_unknown='infrequent_if_exist'),
#                                   ['month'])]),
#  'adaboost_reg': AdaBoostRegressor(estimator=DecisionTreeRegressor(), random_state=42),
#  'preproc1__n_jobs': None,
#  'preproc1__remainder': 'drop',
#  'preproc1__sparse_threshold': 0.3,
#  'preproc1__transformer_weights': None,
#  'preproc1__transformers': [('num_transformer',
#    StandardScaler(),
#    ['ffmc', 'dmc', 'dc', 'isi', 'temp', 'rh', 'wind', 'rain']),
#   ('col_transformer',
#    OneHotEncoder(handle_unknown='infrequent_if_exist'),
#    ['month'])],
#  'preproc1__verbose': False,
#  'preproc1__verbose_feature_names_out': True,
#  'preproc1__num_transformer': StandardScaler(),
#  'preproc1__col_transformer': OneHotEncoder(handle_unknown='infrequent_if_exist'),
#  'preproc1__num_transformer__copy': True,
#  'preproc1__num_transformer__with_mean': True,
#  'preproc1__num_transformer__with_std': True,
#  'preproc1__col_transformer__categories': 'auto',
#  'preproc1__col_transformer__drop': None,
#  'preproc1__col_transformer__dtype': numpy.float64,
#  'preproc1__col_transformer__feature_name_combiner': 'concat',
#  'preproc1__col_transformer__handle_unknown': 'infrequent_if_exist',
#  'preproc1__col_transformer__max_categories': None,
#  'preproc1__col_transformer__min_frequency': None,
#  'preproc1__col_transformer__sparse_output': True,
#  'adaboost_reg__estimator__ccp_alpha': 0.0,
#  'adaboost_reg__estimator__criterion': 'squared_error',
#  'adaboost_reg__estimator__max_depth': None,
#  'adaboost_reg__estimator__max_features': None,
#  'adaboost_reg__estimator__max_leaf_nodes': None,
#  'adaboost_reg__estimator__min_impurity_decrease': 0.0,
#  'adaboost_reg__estimator__min_samples_leaf': 1,
#  'adaboost_reg__estimator__min_samples_split': 2,
#  'adaboost_reg__estimator__min_weight_fraction_leaf': 0.0,
#  'adaboost_reg__estimator__monotonic_cst': None,
#  'adaboost_reg__estimator__random_state': None,
#  'adaboost_reg__estimator__splitter': 'best',
#  'adaboost_reg__estimator': DecisionTreeRegressor(),
#  'adaboost_reg__learning_rate': 1.0,
#  'adaboost_reg__loss': 'linear',
#  'adaboost_reg__n_estimators': 50,
#  'adaboost_reg__random_state': 42}

# %%
# Pipeline D = preproc2 + advanced model
pipe2_adv = Pipeline([
    ('preproc2' , preproc2),
    ('adaboost_reg' , AdaBoostRegressor(n_estimators=50 , random_state=42))
])

# %% [markdown]
# # Tune Hyperparams
#
# + Perform GridSearch on each of the four pipelines.
# + Tune at least one hyperparameter per pipeline.
# + Experiment with at least four value combinations per pipeline.

# %%
x_train , x_test , y_train , y_test = train_test_split( X , Y , test_size = 0.3 , random_state = 42 )

# %%
base_params = {
    'nearest_neighbour__n_neighbors': [ 4 , 5 , 6 , 7 ],
    'nearest_neighbour__p' : [ 1 , 2 ],
    'nearest_neighbour__weights': [ 'uniform' , 'distance' ]
}

advanced_params = {
    'adaboost_reg__estimator': [DecisionTreeRegressor() , SVR()],
    'adaboost_reg__loss' : ['linear' , 'square'],
    'adaboost_reg__n_estimators': [ 10 , 50 , 100]
}

scoring = ['neg_root_mean_squared_error']
#{'neg_root_mean_squared_error', 'f1', 'neg_mean_gamma_deviance', 'adjusted_mutual_info_score', 'f1_weighted', 'recall_weighted', 'neg_root_mean_squared_log_error', 'completeness_score', 'jaccard_samples', 'matthews_corrcoef', 'roc_auc_ovr', 'precision_weighted', 'f1_macro', 'accuracy', 'roc_auc_ovo_weighted', 'neg_median_absolute_error', 'jaccard_macro', 'roc_auc_ovo', 'explained_variance', 'neg_mean_poisson_deviance', 'balanced_accuracy', 'homogeneity_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'jaccard', 'precision_samples', 'recall_micro', 'recall_samples', 'roc_auc_ovr_weighted', 'precision', 'average_precision', 'max_error', 'f1_micro', 'v_measure_score', 'precision_micro', 'precision_macro', 'adjusted_rand_score', 'neg_mean_absolute_percentage_error', 'rand_score', 'positive_likelihood_ratio', 'neg_mean_squared_error', 'jaccard_micro', 'neg_negative_likelihood_ratio', 'neg_mean_squared_log_error', 'jaccard_weighted', 'neg_log_loss', 'neg_mean_absolute_error', 'recall_macro', 'top_k_accuracy', 'r2', 'neg_brier_score', 'recall', 'roc_auc', 'f1_samples', 'mutual_info_score'}

# %%
def model_eval(model , params , scoring , x_train , y_train):
    grid_cv = GridSearchCV(
        estimator=model , 
        param_grid=params , 
        scoring=scoring , 
        cv=5 , 
        refit=scoring[0]
    )
    grid_cv.fit(x_train , y_train)

    results_df = pd.DataFrame(grid_cv.cv_results_)
    best_params = grid_cv.best_params_
    best_estimator = grid_cv.best_estimator_

    return results_df , best_params , best_estimator

# %%
evr.sort_values('rank_test_neg_root_mean_squared_error')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 15       0.015626      0.000980         0.011992        0.006643
# 14       0.009913      0.001572         0.005622        0.000550
# 13       0.009344      0.000665         0.006615        0.000241
# 9        0.007552      0.000344         0.008480        0.000853
# 12       0.017309      0.007272         0.028322        0.025449
# 8        0.007804      0.000553         0.008371        0.000464
# 11       0.011056      0.002055         0.008586        0.003364
# 4        0.007921      0.000923         0.006161        0.000547
# 10       0.009653      0.002355         0.013172        0.005507
# 5        0.008861      0.000951         0.022611        0.031895
# 7        0.008027      0.000815         0.006877        0.000334
# 6        0.010899      0.004675         0.006348        0.001136
# 1        0.013824      0.003702         0.015936        0.002028
# 3        0.008125      0.000927         0.007471        0.000794
# 0        0.013557      0.003034         0.028964        0.033513
# 2        0.018692      0.006939         0.021654        0.019719
#
#    param_nearest_neighbour__n_neighbors param_nearest_neighbour__p  \
# 15                                    7                          2
# 14                                    7                          2
# 13                                    7                          1
# 9                                     6                          1
# 12                                    7                          1
# 8                                     6                          1
# 11                                    6                          2
# 4                                     5                          1
# 10                                    6                          2
# 5                                     5                          1
# 7                                     5                          2
# 6                                     5                          2
# 1                                     4                          1
# 3                                     4                          2
# 0                                     4                          1
# 2                                     4                          2
#
#    param_nearest_neighbour__weights  \
# 15                         distance
# 14                          uniform
# 13                         distance
# 9                          distance
# 12                          uniform
# 8                           uniform
# 11                         distance
# 4                           uniform
# 10                          uniform
# 5                          distance
# 7                          distance
# 6                           uniform
# 1                          distance
# 3                          distance
# 0                           uniform
# 2                           uniform
#
#                                                params  \
# 15  {'nearest_neighbour__n_neighbors': 7, 'nearest...
# 14  {'nearest_neighbour__n_neighbors': 7, 'nearest...
# 13  {'nearest_neighbour__n_neighbors': 7, 'nearest...
# 9   {'nearest_neighbour__n_neighbors': 6, 'nearest...
# 12  {'nearest_neighbour__n_neighbors': 7, 'nearest...
# 8   {'nearest_neighbour__n_neighbors': 6, 'nearest...
# 11  {'nearest_neighbour__n_neighbors': 6, 'nearest...
# 4   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 10  {'nearest_neighbour__n_neighbors': 6, 'nearest...
# 5   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 7   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 6   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 1   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 3   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 0   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 2   {'nearest_neighbour__n_neighbors': 4, 'nearest...
#
#     split0_test_neg_root_mean_squared_error  \
# 15                               -54.026398
# 14                               -53.189044
# 13                               -53.402743
# 9                                -54.268888
# 12                               -51.830176
# 8                                -52.066890
# 11                               -54.777259
# 4                                -55.118449
# 10                               -53.519252
# 5                                -56.776209
# 7                                -56.791315
# 6                                -56.088965
# 1                                -60.977986
# 3                                -60.471118
# 0                                -60.749011
# 2                                -60.614982
#
#     split1_test_neg_root_mean_squared_error  \
# 15                               -37.252710
# 14                               -38.717460
# 13                               -36.583941
# 9                                -38.490407
# 12                               -38.460740
# 8                                -41.054598
# 11                               -40.319997
# 4                                -39.807693
# 10                               -42.795012
# 5                                -38.622119
# 7                                -40.035496
# 6                                -42.347075
# 1                                -41.518392
# 3                                -44.690211
# 0                                -43.356357
# 2                                -49.474503
#
#     split2_test_neg_root_mean_squared_error  \
# 15                               -24.469253
# 14                               -24.727829
# 13                               -26.987284
# 9                                -24.785798
# 12                               -28.211899
# 8                                -25.622251
# 11                               -24.499385
# 4                                -26.590040
# 10                               -24.754980
# 5                                -25.445220
# 7                                -24.541698
# 6                                -25.189653
# 1                                -26.480066
# 3                                -25.722423
# 0                                -28.889831
# 2                                -27.470650
#
#     split3_test_neg_root_mean_squared_error  \
# 15                               -91.726650
# 14                               -91.259061
# 13                               -92.195054
# 9                                -92.643001
# 12                               -91.674281
# 8                                -92.173407
# 11                               -92.490718
# 4                                -91.963524
# 10                               -92.157449
# 5                                -92.678252
# 7                                -92.589446
# 6                                -92.033700
# 1                                -92.682510
# 3                                -92.571254
# 0                                -91.703536
# 2                                -91.726712
#
#     split4_test_neg_root_mean_squared_error  \
# 15                               -27.196098
# 14                               -27.357984
# 13                               -28.087286
# 9                                -28.224271
# 12                               -28.683545
# 8                                -28.212823
# 11                               -28.107544
# 4                                -28.097774
# 10                               -28.371121
# 5                                -28.469495
# 7                                -28.223563
# 6                                -28.587385
# 1                                -29.098655
# 3                                -28.828181
# 0                                -28.972809
# 2                                -29.726982
#
#     mean_test_neg_root_mean_squared_error  \
# 15                             -46.934222
# 14                             -47.050275
# 13                             -47.451262
# 9                              -47.682473
# 12                             -47.772128
# 8                              -47.825994
# 11                             -48.038981
# 4                              -48.315496
# 10                             -48.319563
# 5                              -48.398259
# 7                              -48.436304
# 6                              -48.849355
# 1                              -50.151522
# 3                              -50.456637
# 0                              -50.734309
# 2                              -51.802766
#
#     std_test_neg_root_mean_squared_error  \
# 15                             24.676550
# 14                             24.280095
# 13                             24.286884
# 9                              24.707098
# 12                             23.569240
# 8                              24.117267
# 11                             24.626485
# 4                              24.102136
# 10                             24.217958
# 5                              24.700115
# 7                              24.776549
# 6                              24.207057
# 1                              24.511994
# 3                              24.440761
# 0                              23.596398
# 2                              23.479308
#
#     rank_test_neg_root_mean_squared_error
# 15                                      1
# 14                                      2
# 13                                      3
# 9                                       4
# 12                                      5
# 8                                       6
# 11                                      7
# 4                                       8
# 10                                      9
# 5                                      10
# 7                                      11
# 6                                      12
# 1                                      13
# 3                                      14
# 0                                      15
# 2                                      16

# %%
test_models = {
    pipe1_base : base_params , 
    pipe2_base : base_params , 
    pipe1_adv : advanced_params , 
    pipe2_adv : advanced_params
}

# %%
eval_results = {}
best_eval_params = {}
best_estimators = {}

stacked_outputs = []

for key , value in test_models.items():
    eval_result , eval_bestparams , best_est = model_eval( key , value , scoring , x_train , y_train )
    pipe_key = key.steps[0][0] + ', ' + key.steps[1][0]
    eval_result.insert(0 , 'Model-Config' , pipe_key)

    stacked_outputs.append(eval_result)

    eval_results[key.steps[0][0] + ', ' + key.steps[1][0]] = eval_result
    best_eval_params[key.steps[0][0] + ', ' + key.steps[1][0] + ' : ' + str(value)] = eval_bestparams
    best_estimators[key.steps[0][0] + ', ' + key.steps[1][0]] = best_est

models = pd.concat(stacked_outputs)

models.sort_values('mean_test_neg_root_mean_squared_error')
# Out:
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/supermanritz/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#                    Model-Config  mean_fit_time  std_fit_time  mean_score_time  \
# 5        preproc1, adaboost_reg       0.252120      0.058228         0.022277
# 5        preproc2, adaboost_reg       0.236421      0.007026         0.022734
# 4        preproc1, adaboost_reg       0.124208      0.007737         0.012943
# 4        preproc2, adaboost_reg       0.130241      0.018568         0.012597
# 2   preproc2, nearest_neighbour       0.014337      0.005750         0.005725
# 2   preproc1, nearest_neighbour       0.008123      0.001484         0.006484
# 0   preproc2, nearest_neighbour       0.011142      0.001758         0.012944
# 3   preproc2, nearest_neighbour       0.010907      0.002718         0.006389
# 1   preproc2, nearest_neighbour       0.010994      0.001692         0.007334
# 0   preproc1, nearest_neighbour       0.008384      0.001777         0.005648
# 4   preproc2, nearest_neighbour       0.011803      0.001525         0.008438
# 3   preproc1, nearest_neighbour       0.010570      0.001885         0.017546
# 1   preproc1, nearest_neighbour       0.007941      0.000384         0.006681
# 5   preproc2, nearest_neighbour       0.010590      0.001109         0.008411
# 6   preproc2, nearest_neighbour       0.010989      0.001342         0.010342
# 7   preproc2, nearest_neighbour       0.014832      0.003947         0.011348
# 6   preproc1, nearest_neighbour       0.009990      0.002162         0.007794
# 8   preproc2, nearest_neighbour       0.014956      0.003173         0.011441
# 7   preproc1, nearest_neighbour       0.011511      0.003195         0.016021
# 5   preproc1, nearest_neighbour       0.012748      0.005004         0.019225
# 10  preproc1, nearest_neighbour       0.016983      0.013777         0.014082
# 4   preproc1, nearest_neighbour       0.009144      0.000941         0.006586
# 9   preproc2, nearest_neighbour       0.027344      0.014689         0.020727
# 11  preproc1, nearest_neighbour       0.023136      0.009362         0.024542
# 8   preproc1, nearest_neighbour       0.010669      0.003114         0.030711
# 12  preproc1, nearest_neighbour       0.012392      0.002595         0.014975
# 9   preproc1, nearest_neighbour       0.009028      0.001097         0.008311
# 13  preproc1, nearest_neighbour       0.016326      0.002976         0.019208
# 13  preproc2, nearest_neighbour       0.009831      0.000765         0.009590
# 11  preproc2, nearest_neighbour       0.013131      0.002713         0.015801
# 12  preproc2, nearest_neighbour       0.011018      0.001098         0.006509
# 14  preproc1, nearest_neighbour       0.013306      0.002948         0.012901
# 10  preproc2, nearest_neighbour       0.020421      0.006071         0.018273
# 15  preproc1, nearest_neighbour       0.008019      0.000508         0.009757
# 15  preproc2, nearest_neighbour       0.011300      0.000869         0.006715
# 14  preproc2, nearest_neighbour       0.015875      0.006830         0.011538
# 0        preproc2, adaboost_reg       0.040205      0.001158         0.007958
# 0        preproc1, adaboost_reg       0.042316      0.009164         0.007679
# 2        preproc1, adaboost_reg       0.248476      0.019690         0.026656
# 1        preproc1, adaboost_reg       0.148419      0.015087         0.013697
# 2        preproc2, adaboost_reg       0.253341      0.019433         0.023842
# 1        preproc2, adaboost_reg       0.133522      0.007117         0.014177
# 3        preproc1, adaboost_reg       0.034726      0.004212         0.007185
# 3        preproc2, adaboost_reg       0.035535      0.001547         0.008250
# 8        preproc2, adaboost_reg       0.082287      0.015059         0.013497
# 6        preproc2, adaboost_reg       0.075851      0.016746         0.016444
# 7        preproc2, adaboost_reg       0.087555      0.016261         0.014831
# 10       preproc1, adaboost_reg       0.128179      0.040797         0.032971
# 9        preproc1, adaboost_reg       0.102949      0.033063         0.018190
# 8        preproc1, adaboost_reg       0.093175      0.020635         0.013276
# 7        preproc1, adaboost_reg       0.087666      0.018497         0.017541
# 6        preproc1, adaboost_reg       0.079217      0.015847         0.014043
# 11       preproc1, adaboost_reg       0.098571      0.034816         0.019254
# 10       preproc2, adaboost_reg       0.101087      0.035450         0.017964
# 9        preproc2, adaboost_reg       0.101150      0.029964         0.018058
# 11       preproc2, adaboost_reg       0.109053      0.045073         0.017349
#
#     std_score_time param_nearest_neighbour__n_neighbors  \
# 5         0.002863                                  NaN
# 5         0.001698                                  NaN
# 4         0.000724                                  NaN
# 4         0.000610                                  NaN
# 2         0.000931                                    4
# 2         0.000932                                    4
# 0         0.004877                                    4
# 3         0.001085                                    4
# 1         0.000375                                    4
# 0         0.000454                                    4
# 4         0.002155                                    5
# 3         0.015688                                    4
# 1         0.001606                                    4
# 5         0.002589                                    5
# 6         0.006238                                    5
# 7         0.006286                                    5
# 6         0.003807                                    5
# 8         0.003855                                    6
# 7         0.012476                                    5
# 5         0.015989                                    5
# 10        0.011050                                    6
# 4         0.001215                                    5
# 9         0.015064                                    6
# 11        0.012715                                    6
# 8         0.025262                                    6
# 12        0.008845                                    7
# 9         0.001322                                    6
# 13        0.010061                                    7
# 13        0.003738                                    7
# 11        0.006904                                    6
# 12        0.000907                                    7
# 14        0.004777                                    7
# 10        0.009364                                    6
# 15        0.003512                                    7
# 15        0.001600                                    7
# 14        0.007530                                    7
# 0         0.000518                                  NaN
# 0         0.000693                                  NaN
# 2         0.009115                                  NaN
# 1         0.001340                                  NaN
# 2         0.003059                                  NaN
# 1         0.002343                                  NaN
# 3         0.001113                                  NaN
# 3         0.001070                                  NaN
# 8         0.002575                                  NaN
# 6         0.005725                                  NaN
# 7         0.002330                                  NaN
# 10        0.034817                                  NaN
# 9         0.005153                                  NaN
# 8         0.003764                                  NaN
# 7         0.006758                                  NaN
# 6         0.003706                                  NaN
# 11        0.007285                                  NaN
# 10        0.006499                                  NaN
# 9         0.005368                                  NaN
# 11        0.006235                                  NaN
#
#    param_nearest_neighbour__p param_nearest_neighbour__weights  \
# 5                         NaN                              NaN
# 5                         NaN                              NaN
# 4                         NaN                              NaN
# 4                         NaN                              NaN
# 2                           2                          uniform
# 2                           2                          uniform
# 0                           1                          uniform
# 3                           2                         distance
# 1                           1                         distance
# 0                           1                          uniform
# 4                           1                          uniform
# 3                           2                         distance
# 1                           1                         distance
# 5                           1                         distance
# 6                           2                          uniform
# 7                           2                         distance
# 6                           2                          uniform
# 8                           1                          uniform
# 7                           2                         distance
# 5                           1                         distance
# 10                          2                          uniform
# 4                           1                          uniform
# 9                           1                         distance
# 11                          2                         distance
# 8                           1                          uniform
# 12                          1                          uniform
# 9                           1                         distance
# 13                          1                         distance
# 13                          1                         distance
# 11                          2                         distance
# 12                          1                          uniform
# 14                          2                          uniform
# 10                          2                          uniform
# 15                          2                         distance
# 15                          2                         distance
# 14                          2                          uniform
# 0                         NaN                              NaN
# 0                         NaN                              NaN
# 2                         NaN                              NaN
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 1                         NaN                              NaN
# 3                         NaN                              NaN
# 3                         NaN                              NaN
# 8                         NaN                              NaN
# 6                         NaN                              NaN
# 7                         NaN                              NaN
# 10                        NaN                              NaN
# 9                         NaN                              NaN
# 8                         NaN                              NaN
# 7                         NaN                              NaN
# 6                         NaN                              NaN
# 11                        NaN                              NaN
# 10                        NaN                              NaN
# 9                         NaN                              NaN
# 11                        NaN                              NaN
#
#                                                params  \
# 5   {'adaboost_reg__estimator': DecisionTreeRegres...
# 5   {'adaboost_reg__estimator': DecisionTreeRegres...
# 4   {'adaboost_reg__estimator': DecisionTreeRegres...
# 4   {'adaboost_reg__estimator': DecisionTreeRegres...
# 2   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 2   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 0   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 3   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 1   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 0   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 4   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 3   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 1   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 5   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 6   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 7   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 6   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 8   {'nearest_neighbour__n_neighbors': 6, 'nearest...
# 7   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 5   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# ...
# 9                                -92.291035
# 8                                -92.291035
# 7                                -92.291035
# 6                                -92.291035
# 11                               -92.291035
# 10                               -92.118801
# 9                                -92.118801
# 11                               -92.118801
#
#     split4_test_neg_root_mean_squared_error  \
# 5                                -26.027226
# 5                                -26.112122
# 4                                -26.028239
# 4                                -25.922810
# 2                                -28.743845
# 2                                -29.726982
# 0                                -29.186149
# 3                                -28.548690
# 1                                -29.107045
# 0                                -28.972809
# 4                                -28.152125
# 3                                -28.828181
# 1                                -29.098655
# 5                                -28.395901
# 6                                -28.279224
# 7                                -28.299747
# 6                                -28.587385
# 8                                -28.893750
# 7                                -28.223563
# 5                                -28.469495
# 10                               -28.371121
# 4                                -28.097774
# 9                                -28.441384
# 11                               -28.107544
# 8                                -28.212823
# 12                               -28.683545
# 9                                -28.224271
# 13                               -28.087286
# 13                               -28.097718
# 11                               -27.286695
# 12                               -28.249283
# 14                               -27.357984
# 10                               -27.250394
# 15                               -27.196098
# 15                               -27.031632
# 14                               -26.875867
# 0                                -26.978090
# 0                                -29.957010
# 2                                -28.828592
# 1                                -28.842716
# 2                                -28.916280
# 1                                -26.380309
# 3                                -26.446116
# 3                                -26.430809
# 8                                -26.133602
# 6                                -26.133602
# 7                                -26.133602
# 10                               -26.153161
# 9                                -26.153161
# 8                                -26.153161
# 7                                -26.153161
# 6                                -26.153161
# 11                               -26.153161
# 10                               -26.133602
# 9                                -26.133602
# 11                               -26.133602
#
#     mean_test_neg_root_mean_squared_error  \
# 5                              -53.644419
# 5                              -53.505097
# 4                              -53.478452
# 4                              -52.880069
# 2                              -51.844718
# 2                              -51.802766
# 0                              -51.389774
# 3                              -50.998227
# 1                              -50.886641
# 0                              -50.734309
# 4                              -50.566687
# 3                              -50.456637
# 1                              -50.151522
# 5                              -49.771879
# 6                              -49.161189
# 7                              -49.066773
# 6                              -48.849355
# 8                              -48.464493
# 7                              -48.436304
# 5                              -48.398259
# 10                             -48.319563
# 4                              -48.315496
# 9                              -48.297432
# 11                             -48.038981
# 8                              -47.825994
# 12                             -47.772128
# 9                              -47.682473
# 13                             -47.451262
# 13                             -47.427560
# 11                             -47.413580
# 12                             -47.338730
# 14                             -47.050275
# 10                             -47.021158
# 15                             -46.934222
# 15                             -46.896808
# 14                             -46.597245
# 0                              -46.573758
# 0                              -45.674081
# 2                              -45.121920
# 1                              -44.970402
# 2                              -44.709933
# 1                              -43.836843
# 3                              -43.509954
# 3                              -43.427968
# 8                              -42.179302
# 6                              -42.179302
# 7                              -42.179302
# 10                             -42.165954
# 9                              -42.165954
# 8                              -42.165954
# 7                              -42.165954
# 6                              -42.165954
# 11                             -42.165954
# 10                             -42.145531
# 9                              -42.145531
# 11                             -42.145531
#
#     std_test_neg_root_mean_squared_error  \
# 5                              35.594024
# 5                              35.517959
# 4                              35.449538
# 4                              34.886093
# 2                              23.071057
# 2                              23.479308
# 0                              22.192233
# 3                              24.213755
# 1                              23.551672
# 0                              23.596398
# 4                              22.756956
# 3                              24.440761
# 1                              24.511994
# 5                              23.797224
# 6                              23.741839
# 7                              24.567195
# 6                              24.207057
# 8                              23.048809
# 7                              24.776549
# 5                              24.700115
# 10                             24.217958
# 4                              24.102136
# 9                              23.994422
# 11                             24.626485
# 8                              24.117267
# 12                             23.569240
# 9                              24.707098
# 13                             24.286884
# 13                             24.229680
# 11                             24.689865
# 12                             23.493997
# 14                             24.280095
# 10                             24.104858
# 15                             24.676550
# 15                             25.015213
# 14                             24.634804
# 0                              26.454761
# 0                              26.766902
# 2                              27.172468
# 1                              27.231819
# 2                              27.177857
# 1                              26.396527
# 3                              25.628542
# 3                              26.932553
# 8                              26.270743
# 6                              26.270743
# 7                              26.270743
# 10                             26.280600
# 9                              26.280600
# 8                              26.280600
# 7                              26.280600
# 6                              26.280600
# 11                             26.280600
# 10                             26.206336
# 9                              26.206336
# 11                             26.206336
#
#     rank_test_neg_root_mean_squared_error param_adaboost_reg__estimator  \
# 5                                      12       DecisionTreeRegressor()
# 5                                      12       DecisionTreeRegressor()
# 4                                      11       DecisionTreeRegressor()
# 4                                      11       DecisionTreeRegressor()
# 2                                      16                           NaN
# 2                                      16                           NaN
# 0                                      15                           NaN
# 3                                      14                           NaN
# 1                                      13                           NaN
# 0                                      15                           NaN
# 4                                      12                           NaN
# 3                                      14                           NaN
# 1                                      13                           NaN
# 5                                      11                           NaN
# 6                                      10                           NaN
# 7                                       9                           NaN
# 6                                      12                           NaN
# 8                                       8                           NaN
# 7                                      11                           NaN
# 5                                      10                           NaN
# 10                                      9                           NaN
# 4                                       8                           NaN
# 9                                       7                           NaN
# 11                                      7                           NaN
# 8                                       6                           NaN
# 12                                      5                           NaN
# 9                                       4                           NaN
# 13                                      3                           NaN
# 13                                      6                           NaN
# 11                                      5                           NaN
# 12                                      4                           NaN
# 14                                      2                           NaN
# 10                                      3                           NaN
# 15                                      1                           NaN
# 15                                      2                           NaN
# 14                                      1                           NaN
# 0                                      10       DecisionTreeRegressor()
# 0                                      10       DecisionTreeRegressor()
# 2                                       9       DecisionTreeRegressor()
# 1                                       8       DecisionTreeRegressor()
# 2                                       9       DecisionTreeRegressor()
# 1                                       8       DecisionTreeRegressor()
# 3                                       7       DecisionTreeRegressor()
# 3                                       7       DecisionTreeRegressor()
# 8                                       4                         SVR()
# 6                                       4                         SVR()
# 7                                       4                         SVR()
# 10                                      1                         SVR()
# 9                                       1                         SVR()
# 8                                       1                         SVR()
# 7                                       1                         SVR()
# 6                                       1                         SVR()
# 11                                      1                         SVR()
# 10                                      1                         SVR()
# 9                                       1                         SVR()
# 11                                      1                         SVR()
#
#    param_adaboost_reg__loss param_adaboost_reg__n_estimators
# 5                    square                              100
# 5                    square                              100
# 4                    square                               50
# 4                    square                               50
# 2                       NaN                              NaN
# 2                       NaN                              NaN
# 0                       NaN                              NaN
# 3                       NaN                              NaN
# 1                       NaN                              NaN
# 0                       NaN                              NaN
# 4                       NaN                              NaN
# 3                       NaN                              NaN
# 1                       NaN                              NaN
# 5                       NaN                              NaN
# 6                       NaN                              NaN
# 7                       NaN                              NaN
# 6                       NaN                              NaN
# 8                       NaN                              NaN
# 7                       NaN                              NaN
# 5                       NaN                              NaN
# 10                      NaN                              NaN
# 4                       NaN                              NaN
# 9                       NaN                              NaN
# 11                      NaN                              NaN
# 8                       NaN                              NaN
# 12                      NaN                              NaN
# 9                       NaN                              NaN
# 13                      NaN                              NaN
# 13                      NaN                              NaN
# 11                      NaN                              NaN
# 12                      NaN                              NaN
# 14                      NaN                              NaN
# 10                      NaN                              NaN
# 15                      NaN                              NaN
# 15                      NaN                              NaN
# 14                      NaN                              NaN
# 0                    linear                               10
# 0                    linear                               10
# 2                    linear                              100
# 1                    linear                               50
# 2                    linear                              100
# 1                    linear                               50
# 3                    square                               10
# 3                    square                               10
# 8                    linear                              100
# 6                    linear                               10
# 7                    linear                               50
# 10                   square                               50
# 9                    square                               10
# 8                    linear                              100
# 7                    linear                               50
# 6                    linear                               10
# 11                   square                              100
# 10                   square                               50
# 9                    square                               10
# 11                   square                              100

# %%
models.sort_values('mean_test_neg_root_mean_squared_error' , ascending=False)
# Out:
#                    Model-Config  mean_fit_time  std_fit_time  mean_score_time  \
# 11       preproc2, adaboost_reg       0.109053      0.045073         0.017349
# 10       preproc2, adaboost_reg       0.101087      0.035450         0.017964
# 9        preproc2, adaboost_reg       0.101150      0.029964         0.018058
# 11       preproc1, adaboost_reg       0.098571      0.034816         0.019254
# 6        preproc1, adaboost_reg       0.079217      0.015847         0.014043
# 7        preproc1, adaboost_reg       0.087666      0.018497         0.017541
# 8        preproc1, adaboost_reg       0.093175      0.020635         0.013276
# 9        preproc1, adaboost_reg       0.102949      0.033063         0.018190
# 10       preproc1, adaboost_reg       0.128179      0.040797         0.032971
# 6        preproc2, adaboost_reg       0.075851      0.016746         0.016444
# 7        preproc2, adaboost_reg       0.087555      0.016261         0.014831
# 8        preproc2, adaboost_reg       0.082287      0.015059         0.013497
# 3        preproc2, adaboost_reg       0.035535      0.001547         0.008250
# 3        preproc1, adaboost_reg       0.034726      0.004212         0.007185
# 1        preproc2, adaboost_reg       0.133522      0.007117         0.014177
# 2        preproc2, adaboost_reg       0.253341      0.019433         0.023842
# 1        preproc1, adaboost_reg       0.148419      0.015087         0.013697
# 2        preproc1, adaboost_reg       0.248476      0.019690         0.026656
# 0        preproc1, adaboost_reg       0.042316      0.009164         0.007679
# 0        preproc2, adaboost_reg       0.040205      0.001158         0.007958
# 14  preproc2, nearest_neighbour       0.015875      0.006830         0.011538
# 15  preproc2, nearest_neighbour       0.011300      0.000869         0.006715
# 15  preproc1, nearest_neighbour       0.008019      0.000508         0.009757
# 10  preproc2, nearest_neighbour       0.020421      0.006071         0.018273
# 14  preproc1, nearest_neighbour       0.013306      0.002948         0.012901
# 12  preproc2, nearest_neighbour       0.011018      0.001098         0.006509
# 11  preproc2, nearest_neighbour       0.013131      0.002713         0.015801
# 13  preproc2, nearest_neighbour       0.009831      0.000765         0.009590
# 13  preproc1, nearest_neighbour       0.016326      0.002976         0.019208
# 9   preproc1, nearest_neighbour       0.009028      0.001097         0.008311
# 12  preproc1, nearest_neighbour       0.012392      0.002595         0.014975
# 8   preproc1, nearest_neighbour       0.010669      0.003114         0.030711
# 11  preproc1, nearest_neighbour       0.023136      0.009362         0.024542
# 9   preproc2, nearest_neighbour       0.027344      0.014689         0.020727
# 4   preproc1, nearest_neighbour       0.009144      0.000941         0.006586
# 10  preproc1, nearest_neighbour       0.016983      0.013777         0.014082
# 5   preproc1, nearest_neighbour       0.012748      0.005004         0.019225
# 7   preproc1, nearest_neighbour       0.011511      0.003195         0.016021
# 8   preproc2, nearest_neighbour       0.014956      0.003173         0.011441
# 6   preproc1, nearest_neighbour       0.009990      0.002162         0.007794
# 7   preproc2, nearest_neighbour       0.014832      0.003947         0.011348
# 6   preproc2, nearest_neighbour       0.010989      0.001342         0.010342
# 5   preproc2, nearest_neighbour       0.010590      0.001109         0.008411
# 1   preproc1, nearest_neighbour       0.007941      0.000384         0.006681
# 3   preproc1, nearest_neighbour       0.010570      0.001885         0.017546
# 4   preproc2, nearest_neighbour       0.011803      0.001525         0.008438
# 0   preproc1, nearest_neighbour       0.008384      0.001777         0.005648
# 1   preproc2, nearest_neighbour       0.010994      0.001692         0.007334
# 3   preproc2, nearest_neighbour       0.010907      0.002718         0.006389
# 0   preproc2, nearest_neighbour       0.011142      0.001758         0.012944
# 2   preproc1, nearest_neighbour       0.008123      0.001484         0.006484
# 2   preproc2, nearest_neighbour       0.014337      0.005750         0.005725
# 4        preproc2, adaboost_reg       0.130241      0.018568         0.012597
# 4        preproc1, adaboost_reg       0.124208      0.007737         0.012943
# 5        preproc2, adaboost_reg       0.236421      0.007026         0.022734
# 5        preproc1, adaboost_reg       0.252120      0.058228         0.022277
#
#     std_score_time param_nearest_neighbour__n_neighbors  \
# 11        0.006235                                  NaN
# 10        0.006499                                  NaN
# 9         0.005368                                  NaN
# 11        0.007285                                  NaN
# 6         0.003706                                  NaN
# 7         0.006758                                  NaN
# 8         0.003764                                  NaN
# 9         0.005153                                  NaN
# 10        0.034817                                  NaN
# 6         0.005725                                  NaN
# 7         0.002330                                  NaN
# 8         0.002575                                  NaN
# 3         0.001070                                  NaN
# 3         0.001113                                  NaN
# 1         0.002343                                  NaN
# 2         0.003059                                  NaN
# 1         0.001340                                  NaN
# 2         0.009115                                  NaN
# 0         0.000693                                  NaN
# 0         0.000518                                  NaN
# 14        0.007530                                    7
# 15        0.001600                                    7
# 15        0.003512                                    7
# 10        0.009364                                    6
# 14        0.004777                                    7
# 12        0.000907                                    7
# 11        0.006904                                    6
# 13        0.003738                                    7
# 13        0.010061                                    7
# 9         0.001322                                    6
# 12        0.008845                                    7
# 8         0.025262                                    6
# 11        0.012715                                    6
# 9         0.015064                                    6
# 4         0.001215                                    5
# 10        0.011050                                    6
# 5         0.015989                                    5
# 7         0.012476                                    5
# 8         0.003855                                    6
# 6         0.003807                                    5
# 7         0.006286                                    5
# 6         0.006238                                    5
# 5         0.002589                                    5
# 1         0.001606                                    4
# 3         0.015688                                    4
# 4         0.002155                                    5
# 0         0.000454                                    4
# 1         0.000375                                    4
# 3         0.001085                                    4
# 0         0.004877                                    4
# 2         0.000932                                    4
# 2         0.000931                                    4
# 4         0.000610                                  NaN
# 4         0.000724                                  NaN
# 5         0.001698                                  NaN
# 5         0.002863                                  NaN
#
#    param_nearest_neighbour__p param_nearest_neighbour__weights  \
# 11                        NaN                              NaN
# 10                        NaN                              NaN
# 9                         NaN                              NaN
# 11                        NaN                              NaN
# 6                         NaN                              NaN
# 7                         NaN                              NaN
# 8                         NaN                              NaN
# 9                         NaN                              NaN
# 10                        NaN                              NaN
# 6                         NaN                              NaN
# 7                         NaN                              NaN
# 8                         NaN                              NaN
# 3                         NaN                              NaN
# 3                         NaN                              NaN
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 0                         NaN                              NaN
# 0                         NaN                              NaN
# 14                          2                          uniform
# 15                          2                         distance
# 15                          2                         distance
# 10                          2                          uniform
# 14                          2                          uniform
# 12                          1                          uniform
# 11                          2                         distance
# 13                          1                         distance
# 13                          1                         distance
# 9                           1                         distance
# 12                          1                          uniform
# 8                           1                          uniform
# 11                          2                         distance
# 9                           1                         distance
# 4                           1                          uniform
# 10                          2                          uniform
# 5                           1                         distance
# 7                           2                         distance
# 8                           1                          uniform
# 6                           2                          uniform
# 7                           2                         distance
# 6                           2                          uniform
# 5                           1                         distance
# 1                           1                         distance
# 3                           2                         distance
# 4                           1                          uniform
# 0                           1                          uniform
# 1                           1                         distance
# 3                           2                         distance
# 0                           1                          uniform
# 2                           2                          uniform
# 2                           2                          uniform
# 4                         NaN                              NaN
# 4                         NaN                              NaN
# 5                         NaN                              NaN
# 5                         NaN                              NaN
#
#                                                params  \
# 11  {'adaboost_reg__estimator': SVR(), 'adaboost_r...
# 10  {'adaboost_reg__estimator': SVR(), 'adaboost_r...
# 9   {'adaboost_reg__estimator': SVR(), 'adaboost_r...
# 11  {'adaboost_reg__estimator': SVR(), 'adaboost_r...
# 6   {'adaboost_reg__estimator': SVR(), 'adaboost_r...
# 7   {'adaboost_reg__estimator': SVR(), 'adaboost_r...
# 8   {'adaboost_reg__estimator': SVR(), 'adaboost_r...
# 9   {'adaboost_reg__estimator': SVR(), 'adaboost_r...
# 10  {'adaboost_reg__estimator': SVR(), 'adaboost_r...
# 6   {'adaboost_reg__estimator': SVR(), 'adaboost_r...
# 7   {'adaboost_reg__estimator': SVR(), 'adaboost_r...
# 8   {'adaboost_reg__estimator': SVR(), 'adaboost_r...
# 3   {'adaboost_reg__estimator': DecisionTreeRegres...
# 3   {'adaboost_reg__estimator': DecisionTreeRegres...
# 1   {'adaboost_reg__estimator': DecisionTreeRegres...
# 2   {'adaboost_reg__estimator': DecisionTreeRegres...
# 1   {'adaboost_reg__estimator': DecisionTreeRegres...
# 2   {'adaboost_reg__estimator': DecisionTreeRegres...
# 0   {'adaboost_reg__estimator': DecisionTreeRegres...
# 0   {'adaboost_reg__estimator': DecisionTreeRegres...
# 14  {'nearest_neighbour__n_neighbors': 7, 'nearest...
# 15  {'nearest_neighbour__n_neighbors': 7, 'nearest...
# 15  {'nearest_neighbour__n_neighbors': 7, 'nearest...
# 10  {'nearest_neighbour__n_neighbors': 6, 'nearest...
# 14  {'nearest_neighbour__n_neighbors': 7, 'nearest...
# 12  {'nearest_neighbour__n_neighbors': 7, 'nearest...
# 11  {'nearest_neighbour__n_neighbors': 6, 'nearest...
# 13  {'nearest_neighbour__n_neighbors': 7, 'nearest...
# 13  {'nearest_neighbour__n_neighbors': 7, 'nearest...
# 9   {'nearest_neighbour__n_neighbors': 6, 'nearest...
# 12  {'nearest_neighbour__n_neighbors': 7, 'nearest...
# 8   {'nearest_neighbour__n_neighbors': 6, 'nearest...
# 11  {'nearest_neighbour__n_neighbors': 6, 'nearest...
# 9   {'nearest_neighbour__n_neighbors': 6, 'nearest...
# 4   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 10  {'nearest_neighbour__n_neighbors': 6, 'nearest...
# 5   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 7   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 8   {'nearest_neighbour__n_neighbors': 6, 'nearest...
# 6   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 7   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 6   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 5   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 1   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 3   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 4   {'nearest_neighbour__n_neighbors': 5, 'nearest...
# 0   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 1   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 3   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 0   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 2   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 2   {'nearest_neighbour__n_neighbors': 4, 'nearest...
# 4   {'adaboost_reg__estimator': DecisionTreeRegres...
# 4   {'adaboost_reg__estimator': DecisionTreeRegres...
# 5   {'adaboost_reg__estimator': DecisionTreeRegres...
# 5   {'adaboost_reg__estimator': DecisionTreeRegres...
#
#     split0_test_neg_root_mean_squared_error  \
# 11                               -44.826537
# 10                               -44.826537
# 9                                -44.826537
# 11                               -44.815972
# 6                                -44.815972
# 7                                -44.815972
# 8                                -44.815972
# 9                                -44.815972
# 10                               -44.815972
# 6                                -44.826537
# 7                                -44.826537
# 8                                -44.826537
# 3                                -45.488795
# 3                                -46.306619
# 1                                -51.424635
# 2                                -51.334891
# 1                                -51.708193
# 2                                -52.222447
# 0                                -52.625656
# 0                                -51.105161
# 14                               -53.111261
# 15                               -54.593670
# 15                               -54.026398
# 10                               -50.929606
# 14                               -53.189044
# 12                               -50.255362
# 11                               -54.006743
# 13                               -52.904580
# 13                               -53.402743
# 9                                -54.268888
# 12                               -51.830176
# 8                                -52.066890
# 11                               -54.777259
# 9                                -54.674615
# 4                                -55.118449
# 10                               -53.519252
# 5                                -56.776209
# 7                                -56.791315
# 8                                -52.175766
# 6                                -56.088965
# 7                                -56.268270
# 6                                -53.076085
# 5                                -56.451862
# 1                                -60.977986
# 3                                -60.471118
# 4                                -54.144371
# 0                                -60.749011
# 1                                -58.682066
# 3                                -59.469095
# 0                                -54.743557
# 2                                -60.614982
# 2                                -56.241146
# 4                                -98.500609
# 4                                -98.297605
# 5                               -101.183524
# 5                                -98.952641
#
#     split1_test_neg_root_mean_squared_error  \
# 11                               -24.727687
# 10                               -24.727687
# 9                                -24.727687
# 11                               -24.695945
# 6                                -24.695945
# 7                                -24.695945
# 8                                -24.695945
# 9                                -24.695945
# 10                               -24.695945
# 6                                -24.727687
# 7                                -24.727687
# 8                                -24.727687
# 3                                -25.500579
# 3                                -27.328335
# 1                                -25.849226
# 2                                -25.257579
# 1                                -26.000326
# 2                                -26.262858
# 0                                -27.668411
# 0                                -33.435931
# 14                               -35.654544
# 15                               -35.672753
# 15                               -37.252710
# 10                               -38.669865
# 14                               -38.717460
# 12                               -36.952464
# 11                               -38.011160
# 13                               -36.020471
# 13                               -36.583941
# 9                                -38.490407
# 12                               -38.460740
# 8                                -41.054598
# 11                               -40.319997
# 9                                -38.070439
# 4                                -39.807693
# 10                               -42.795012
# 5                                -38.622119
# 7                                -40.035496
# 8                                -40.285389
# 6                                -42.347075
# 7                                -41.615264
# 6                                -44.076449
# 5                                -41.343076
# 1                                -41.518392
# 3                                -44.690211
# 4                                -46.058074
# 0                                -43.356357
# 1                                -42.029045
# 3                                -47.075626
# 0                                -45.155193
# 2                                -49.474503
# 2                                -52.649908
# 4                                -24.218378
# 4                                -24.529624
# 5                                -24.513685
# 5                                -24.607704
#
#     split2_test_neg_root_mean_squared_error  \
# 11                               -22.921027
# 10                               -22.921027
# 9                                -22.921027
# 11                               -22.873660
# 6                                -22.873660
# 7                                -22.873660
# 8                                -22.873660
# 9                                -22.873660
# 10                               -22.873660
# 6                                -22.921027
# 7                                -22.921027
# 8                                -22.921027
# 3                                -24.701200
# 3                                -25.121067
# 1                                -23.051657
# 2                                -22.882708
# 1                                -22.816159
# 2                                -22.907630
# 0                                -22.973430
# 0                                -25.146880
# 14                               -25.569049
# 15                               -24.863505
# 15                               -24.469253
# 10                               -26.446407
# 14                               -24.727829
# 12                               -29.583140
# 11                               -25.355937
# 13                               -27.788388
# 13                               -26.987284
# 9                                -24.785798
# 12                               -28.211899
# 8                                -25.622251
# 11                               -24.499385
# 9                                -28.071124
# 4                                -26.590040
# 10                               -24.754980
# 5                                -25.445220
# 7                                -24.541698
# 8                                -29.632314
# 6                                -25.189653
# 7                                -25.973049
# 6                                -27.798854
# 5                                -29.778281
# 1                                -26.480066
# 3                                -25.722423
# 4                                -32.395259
# 0                                -28.889831
# 1                                -31.493919
# 3                                -26.932367
# 0                                -35.605821
# 2                                -27.470650
# 2                                -29.588981
# 4                                -23.196471
# 4                                -23.102138
# 5                                -23.176519
# 5                                -23.181162
#
#     split3_test_neg_root_mean_squared_error  \
# 11                               -92.118801
# 10                               -92.118801
# 9                                -92.118801
# 11                               -92.291035
# 6                                -92.291035
# 7                                -92.291035
# 8                                -92.291035
# 9                                -92.291035
# 10                               -92.291035
# 6                                -92.287658
# 7                                -92.287658
# 8                                -92.287658
# 3                                -95.018458
# 3                                -92.347635
# 1                                -92.478386
# 2                                -95.158207
# 1                                -95.484614
# 2                                -95.388074
# 0                                -95.145900
# 0                                -96.202727
# 14                               -91.775504
# 15                               -92.322479
# 15                               -91.726650
# 10                               -91.809518
# 14                               -91.259061
# 12                               -91.653402
# 11                               -92.407367
# 13                               -92.326643
# 13                               -92.195054
# 9                                -92.643001
# 12                               -91.674281
# 8                                -92.173407
# 11                               -92.490718
# 9                                -92.229599
# 4                                -91.963524
# 10                               -92.157449
# 5                                -92.678252
# 7                                -92.589446
# 8                                -91.335248
# 6                                -92.033700
# 7                                -93.177535
# 6                                -92.575331
# 5                                -92.890276
# 1                                -92.682510
# 3                                -92.571254
# 4                                -92.083605
# 0                                -91.703536
# 1                                -93.121131
# 3                                -92.965356
# 0                                -92.258148
# 2                                -91.726712
# 2                                -91.999709
# 4                                -92.562073
# 4                                -95.434655
# 5                                -92.539633
# 5                                -95.453359
#
#     split4_test_neg_root_mean_squared_error  \
# 11                               -26.133602
# 10                               -26.133602
# 9                                -26.133602
# 11                               -26.153161
# 6                                -26.153161
# 7                                -26.153161
# 8                                -26.153161
# 9                                -26.153161
# 10                               -26.153161
# 6                                -26.133602
# 7                                -26.133602
# 8                                -26.133602
# 3                                -26.430809
# 3                                -26.446116
# 1                                -26.380309
# 2                                -28.916280
# 1                                -28.842716
# 2                                -28.828592
# 0                                -29.957010
# 0                                -26.978090
# 14                               -26.875867
# 15                               -27.031632
# 15                               -27.196098
# 10                               -27.250394
# 14                               -27.357984
# 12                               -28.249283
# 11                               -27.286695
# 13                               -28.097718
# 13                               -28.087286
# 9                                -28.224271
# 12                               -28.683545
# 8                                -28.212823
# 11                               -28.107544
# 9                                -28.441384
# 4                                -28.097774
# 10                               -28.371121
# 5                                -28.469495
# 7                                -28.223563
# 8                                -28.893750
# 6                                -28.587385
# 7                                -28.299747
# 6                                -28.279224
# 5                                -28.395901
# 1                                -29.098655
# 3                                -28.828181
# 4                                -28.152125
# 0                                -28.972809
# 1                                -29.107045
# 3                                -28.548690
# 0                                -29.186149
# 2                                -29.726982
# 2                                -28.743845
# 4                                -25.922810
# 4                                -26.028239
# 5                                -26.112122
# 5                                -26.027226
#
#     mean_test_neg_root_mean_squared_error  \
# 11                             -42.145531
# 10                             -42.145531
# 9                              -42.145531
# 11                             -42.165954
# 6                              -42.165954
# 7                              -42.165954
# 8                              -42.165954
# 9                              -42.165954
# 10                             -42.165954
# 6                              -42.179302
# 7                              -42.179302
# 8                              -42.179302
# 3                              -43.427968
# 3                              -43.509954
# 1                              -43.836843
# 2                              -44.709933
# 1                              -44.970402
# 2                              -45.121920
# 0                              -45.674081
# 0                              -46.573758
# 14                             -46.597245
# 15                             -46.896808
# 15                             -46.934222
# 10                             -47.021158
# 14                             -47.050275
# 12                             -47.338730
# 11                             -47.413580
# 13                             -47.427560
# 13                             -47.451262
# 9                              -47.682473
# 12                             -47.772128
# 8                              -47.825994
# 11                             -48.038981
# 9                              -48.297432
# 4                              -48.315496
# 10                             -48.319563
# 5                              -48.398259
# 7                              -48.436304
# 8                              -48.464493
# 6                              -48.849355
# 7                              -49.066773
# 6                              -49.161189
# 5                              -49.771879
# 1                              -50.151522
# 3                              -50.456637
# 4                              -50.566687
# 0                              -50.734309
# 1                              -50.886641
# 3                              -50.998227
# 0                              -51.389774
# 2                              -51.802766
# 2                              -51.844718
# 4                              -52.880069
# 4                              -53.478452
# 5                              -53.505097
# 5                              -53.644419
#
#     std_test_neg_root_mean_squared_error  \
# 11                             26.206336
# 10                             26.206336
# 9                              26.206336
# 11                             26.280600
# 6                              26.280600
# 7                              26.280600
# 8                              26.280600
# 9                              26.280600
# 10                             26.280600
# 6                              26.270743
# 7                              26.270743
# 8                              26.270743
# 3                              26.932553
# 3                              25.628542
# 1                              26.396527
# 2                              27.177857
# 1                              27.231819
# 2                              27.172468
# 0                              26.766902
# 0                              26.454761
# 14                             24.634804
# 15                             25.015213
# 15                             24.676550
# 10                             24.104858
# 14                             24.280095
# 12                             23.493997
# 11                             24.689865
# 13                             24.229680
# 13                             24.286884
# 9                              24.707098
# 12                             23.569240
# 8                              24.117267
# 11                             24.626485
# 9                              23.994422
# 4                              24.102136
# 10                             24.217958
# 5                              24.700115
# 7                              24.776549
# 8                              23.048809
# 6                              24.207057
# 7                              24.567195
# 6                              23.741839
# 5                              23.797224
# 1                              24.511994
# 3                              24.440761
# 4                              22.756956
# 0                              23.596398
# 1                              23.551672
# 3                              24.213755
# 0                              22.192233
# 2                              23.479308
# 2                              23.071057
# 4                              34.886093
# 4                              35.449538
# 5                              35.517959
# 5                              35.594024
#
#     rank_test_neg_root_mean_squared_error param_adaboost_reg__estimator  \
# 11                                      1                         SVR()
# 10                                      1                         SVR()
# 9                                       1                         SVR()
# 11                                      1                         SVR()
# 6                                       1                         SVR()
# 7                                       1                         SVR()
# 8                                       1                         SVR()
# 9                                       1                         SVR()
# 10                                      1                         SVR()
# 6                                       4                         SVR()
# 7                                       4                         SVR()
# 8                                       4                         SVR()
# 3                                       7       DecisionTreeRegressor()
# 3                                       7       DecisionTreeRegressor()
# 1                                       8       DecisionTreeRegressor()
# 2                                       9       DecisionTreeRegressor()
# 1                                       8       DecisionTreeRegressor()
# 2                                       9       DecisionTreeRegressor()
# 0                                      10       DecisionTreeRegressor()
# 0                                      10       DecisionTreeRegressor()
# 14                                      1                           NaN
# 15                                      2                           NaN
# 15                                      1                           NaN
# 10                                      3                           NaN
# 14                                      2                           NaN
# 12                                      4                           NaN
# 11                                      5                           NaN
# 13                                      6                           NaN
# 13                                      3                           NaN
# 9                                       4                           NaN
# 12                                      5                           NaN
# 8                                       6                           NaN
# 11                                      7                           NaN
# 9                                       7                           NaN
# 4                                       8                           NaN
# 10                                      9                           NaN
# 5                                      10                           NaN
# 7                                      11                           NaN
# 8                                       8                           NaN
# 6                                      12                           NaN
# 7                                       9                           NaN
# 6                                      10                           NaN
# 5                                      11                           NaN
# 1                                      13                           NaN
# 3                                      14                           NaN
# 4                                      12                           NaN
# 0                                      15                           NaN
# 1                                      13                           NaN
# 3                                      14                           NaN
# 0                                      15                           NaN
# 2                                      16                           NaN
# 2                                      16                           NaN
# 4                                      11       DecisionTreeRegressor()
# 4                                      11       DecisionTreeRegressor()
# 5                                      12       DecisionTreeRegressor()
# 5                                      12       DecisionTreeRegressor()
#
#    param_adaboost_reg__loss param_adaboost_reg__n_estimators
# 11                   square                              100
# 10                   square                               50
# 9                    square                               10
# 11                   square                              100
# 6                    linear                               10
# 7                    linear                               50
# 8                    linear                              100
# 9                    square                               10
# 10                   square                               50
# 6                    linear                               10
# 7                    linear                               50
# 8                    linear                              100
# 3                    square                               10
# 3                    square                               10
# 1                    linear                               50
# 2                    linear                              100
# 1                    linear                               50
# 2                    linear                              100
# 0                    linear                               10
# 0                    linear                               10
# 14                      NaN                              NaN
# 15                      NaN                              NaN
# 15                      NaN                              NaN
# 10                      NaN                              NaN
# 14                      NaN                              NaN
# 12                      NaN                              NaN
# 11                      NaN                              NaN
# 13                      NaN                              NaN
# 13                      NaN                              NaN
# 9                       NaN                              NaN
# 12                      NaN                              NaN
# 8                       NaN                              NaN
# 11                      NaN                              NaN
# 9                       NaN                              NaN
# 4                       NaN                              NaN
# 10                      NaN                              NaN
# 5                       NaN                              NaN
# 7                       NaN                              NaN
# 8                       NaN                              NaN
# 6                       NaN                              NaN
# 7                       NaN                              NaN
# 6                       NaN                              NaN
# 5                       NaN                              NaN
# 1                       NaN                              NaN
# 3                       NaN                              NaN
# 4                       NaN                              NaN
# 0                       NaN                              NaN
# 1                       NaN                              NaN
# 3                       NaN                              NaN
# 0                       NaN                              NaN
# 2                       NaN                              NaN
# 2                       NaN                              NaN
# 4                    square                               50
# 4                    square                               50
# 5                    square                              100
# 5                    square                              100

# %%
best_eval_params
# Out:
# {"preproc1, nearest_neighbour : {'nearest_neighbour__n_neighbors': [4, 5, 6, 7], 'nearest_neighbour__p': [1, 2], 'nearest_neighbour__weights': ['uniform', 'distance']}": {'nearest_neighbour__n_neighbors': 7,
#   'nearest_neighbour__p': 2,
#   'nearest_neighbour__weights': 'distance'},
#  "preproc2, nearest_neighbour : {'nearest_neighbour__n_neighbors': [4, 5, 6, 7], 'nearest_neighbour__p': [1, 2], 'nearest_neighbour__weights': ['uniform', 'distance']}": {'nearest_neighbour__n_neighbors': 7,
#   'nearest_neighbour__p': 2,
#   'nearest_neighbour__weights': 'uniform'},
#  "preproc1, adaboost_reg : {'adaboost_reg__estimator': [DecisionTreeRegressor(), SVR()], 'adaboost_reg__loss': ['linear', 'square'], 'adaboost_reg__n_estimators': [10, 50, 100]}": {'adaboost_reg__estimator': SVR(),
#   'adaboost_reg__loss': 'linear',
#   'adaboost_reg__n_estimators': 10},
#  "preproc2, adaboost_reg : {'adaboost_reg__estimator': [DecisionTreeRegressor(), SVR()], 'adaboost_reg__loss': ['linear', 'square'], 'adaboost_reg__n_estimators': [10, 50, 100]}": {'adaboost_reg__estimator': SVR(),
#   'adaboost_reg__loss': 'square',
#   'adaboost_reg__n_estimators': 10}}

# %%
best_estimators
# Out:
# {'preproc1, nearest_neighbour': Pipeline(steps=[('preproc1',
#                   ColumnTransformer(transformers=[('num_transformer',
#                                                    StandardScaler(),
#                                                    ['ffmc', 'dmc', 'dc', 'isi',
#                                                     'temp', 'rh', 'wind',
#                                                     'rain']),
#                                                   ('col_transformer',
#                                                    OneHotEncoder(handle_unknown='infrequent_if_exist'),
#                                                    ['month'])])),
#                  ('nearest_neighbour',
#                   KNeighborsRegressor(n_neighbors=7, weights='distance'))]),
#  'preproc2, nearest_neighbour': Pipeline(steps=[('preproc2',
#                   ColumnTransformer(transformers=[('num_transformer',
#                                                    RobustScaler(),
#                                                    ['ffmc', 'dmc', 'dc', 'isi',
#                                                     'temp', 'rh', 'wind',
#                                                     'rain']),
#                                                   ('col_transformer',
#                                                    OneHotEncoder(handle_unknown='infrequent_if_exist'),
#                                                    ['month'])])),
#                  ('nearest_neighbour', KNeighborsRegressor(n_neighbors=7))]),
#  'preproc1, adaboost_reg': Pipeline(steps=[('preproc1',
#                   ColumnTransformer(transformers=[('num_transformer',
#                                                    StandardScaler(),
#                                                    ['ffmc', 'dmc', 'dc', 'isi',
#                                                     'temp', 'rh', 'wind',
#                                                     'rain']),
#                                                   ('col_transformer',
#                                                    OneHotEncoder(handle_unknown='infrequent_if_exist'),
#                                                    ['month'])])),
#                  ('adaboost_reg',
#                   AdaBoostRegressor(estimator=SVR(), n_estimators=10,
#                                     random_state=42))]),
#  'preproc2, adaboost_reg': Pipeline(steps=[('preproc2',
#                   ColumnTransformer(transformers=[('num_transformer',
#                                                    RobustScaler(),
#                                                    ['ffmc', 'dmc', 'dc', 'isi',
#                                                     'temp', 'rh', 'wind',
#                                                     'rain']),
#                                                   ('col_transformer',
#                                                    OneHotEncoder(handle_unknown='infrequent_if_exist'),
#                                                    ['month'])])),
#                  ('adaboost_reg',
#                   AdaBoostRegressor(estimator=SVR(), loss='square',
#                                     n_estimators=10, random_state=42))])}

# %% [markdown]
# # Evaluate
#
# + Which model has the best performance? - The model using a Robust transformer, with an Adaboost algo + Support Vector Regression utilizing a squared loss metric with 10 estimators appears to have performed the best

# %% [markdown]
# # Export
#
# + Save the best performing model to a pickle file.

# %%
import pickle
pickle.dump(pipe2_adv , open('../trained_model', 'wb'))

# %% [markdown]
# # Explain
#
# + Use SHAP values to explain the following only for the best-performing model:
#
#     - Select an observation in your test set and explain which are the most important features that explain that observation's specific prediction.
#
#     - In general, across the complete training set, which features are the most and least important.
#
# + If you were to remove features from the model, which ones would you remove? Why? How would you test that these features are actually enhancing model performance?

# %% [markdown]
# *(Answer here.)*
#
# <H4>*Note*</H4>
# Shap does not currently support AdaboostRegressor so the first KNearestRegressor entry was used. KNearestRegressor is also not natively support so the explainer was constructed on predicted values.
#
# + The most important features appear to be relative humidity and the wind speed
# + If you were to remove features from the model, which ones would you remove? Why? I would likely start by removing the onehot encoding for months and recode them as larger buckets spanning several months which would also simplify the dataset. Also the ffmc , isi , dc , dmc all appear to have the same impact in the same direction on the predicted values, there could be some correlation going on and all but one could be dropped.
# + How would you test that these features are actually enhancing model performance? Looking at various performance metrics including the precision, accuracy and recall

# %%
import shap
import numpy as np

# %%
pipe2_base_set = pipe2_base.set_params(**{'nearest_neighbour__n_neighbors': 7, 'nearest_neighbour__p': 2, 'nearest_neighbour__weights': 'uniform'})
pipe2_base_set.fit(x_train , np.ravel(y_train))

data_transform = pipe2_base_set.named_steps['preproc2'].transform(x_test)

explainer = shap.explainers.PartitionExplainer(
    pipe2_base_set.named_steps['nearest_neighbour'].predict ,
    data_transform , 
    feature_names = pipe2_base_set.named_steps['preproc2'].get_feature_names_out()
)

shap_values = explainer(data_transform)

shap.plots.waterfall(shap_values[1])
# Out:
# PartitionExplainer explainer: 157it [01:36,  1.43it/s]

# %%
shap.plots.waterfall(shap_values[1] , max_display=22)

# %% [markdown]
# *(Answer here.)*

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-3`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_3.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/production/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-3-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.

# %% [markdown]
# # Reference
#
# Cortez,Paulo and Morais,Anbal. (2008). Forest Fires. UCI Machine Learning Repository. https://doi.org/10.24432/C5D88D.
